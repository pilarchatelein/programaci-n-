# %% [markdown]
# <a href="https://colab.research.google.com/github/pilarchatelein/programaci-n-/blob/main/Practica_parcial_de_Fupro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejercicio 1
import random

n_secreto=random.randint(1,10)

n=int(input("Ingrese el numero secreto: "))
intento=1

while n!=n_secreto:
  n=int(input("Ingrese el numero secreto: "))
  intento+=1

  if n==n_secreto:
    print("¡Felicidades, adivinaste el numero correcto!, es ",n_secreto)

    break
  else:
    print(f"sigue intentando, llevas {intento} intentos")
# Out:
# Ingrese el numero secreto: 7
# Ingrese el numero secreto: 3
# sigue intentando, llevas 2 intentos
# Ingrese el numero secreto: 1
# sigue intentando, llevas 3 intentos
# Ingrese el numero secreto: 6
# sigue intentando, llevas 4 intentos
# Ingrese el numero secreto: 5
# sigue intentando, llevas 5 intentos
# Ingrese el numero secreto: 1
# sigue intentando, llevas 6 intentos
# Ingrese el numero secreto: 2
# sigue intentando, llevas 7 intentos
# Ingrese el numero secreto: 3
# sigue intentando, llevas 8 intentos
# Ingrese el numero secreto: 4
# sigue intentando, llevas 9 intentos
# Ingrese el numero secreto: 7
# sigue intentando, llevas 10 intentos
# Ingrese el numero secreto: 8
# sigue intentando, llevas 11 intentos
# Ingrese el numero secreto: 9
# ¡Felicidades, adivinaste el numero correcto!, es  9

# %%
#ejercicio 2

maxima=0
minimas=0
minimo_dias=0
for i in range(5):
  tem_maxima=int(input("INGRESE LA TEMPERATURA MAXIMA: "))
  tem_minima=int(input("INGRESE LA TEMPERATURA MINIMA: "))

  print(f"La temperatura para el dia {i} fue maxima:{tem_maxima} y la minima fue {tem_minima}")

  if tem_maxima >maxima:
    maxima=tem_maxima
    dia=i

  minimas+=tem_minima


  if tem_minima <0:
    minimo_dias+=1
promedio=minimas/31
print(f"El promedio de temperaturas minimas fue:{promedio} ")
print(f"El dia de mayor temperatura fue {i}, donde hicieron {maxima} grados")
print(f"Se produjero temperaturas bajo cero en {minimo_dias} dias")
# Out:
# INGRESE LA TEMPERATURA MAXIMA: 30
# INGRESE LA TEMPERATURA MINIMA: 1
# La temperatura para el dia 0 fue maxima:30 y la minima fue 1
# INGRESE LA TEMPERATURA MAXIMA: 34
# INGRESE LA TEMPERATURA MINIMA: -1
# La temperatura para el dia 1 fue maxima:34 y la minima fue -1
# INGRESE LA TEMPERATURA MAXIMA: 20
# INGRESE LA TEMPERATURA MINIMA: 7
# La temperatura para el dia 2 fue maxima:20 y la minima fue 7
# INGRESE LA TEMPERATURA MAXIMA: 36
# INGRESE LA TEMPERATURA MINIMA: 3
# La temperatura para el dia 3 fue maxima:36 y la minima fue 3
# INGRESE LA TEMPERATURA MAXIMA: 25
# INGRESE LA TEMPERATURA MINIMA: 5
# La temperatura para el dia 4 fue maxima:25 y la minima fue 5
# El promedio de temperaturas minimas fue:0.4838709677419355
# El dia de mayor temperatura fue 4, donde hicieron 36 grados
# Se produjero temperaturas bajo cero en 0

# %%
import random
intentos=0
n_secreto=random.randint(1,100)
print("Adivina el numero secreto (entre 1 y 100: )")
while intentos <=7:

  n=int(input(f"intento {intentos}: "))
  intentos+=1

  if n<n_secreto:
    print("El numero es demasiado bajo")
  elif n>n_secreto :
    print("El numero es demasiado alto")

  if n==n_secreto and intentos<=7:
    print(f"¡Felicidades! Adivinaste el numero en {intentos} intentos")
    break
  else:
    print("¡Perdiste!, no lograste adivinar el numero correctamente")
print(f"El numero secreto era {n_secreto}")
# Out:
# Adivina el numero secreto (entre 1 y 100: )
# intento 0: 80
# El numero es demasiado bajo
# ¡Perdiste!, no lograste adivinar el numero correctamente
# intento 1: 90
# El numero es demasiado bajo
# ¡Perdiste!, no lograste adivinar el numero correctamente
# intento 2: 100
# El numero es demasiado alto
# ¡Perdiste!, no lograste adivinar el numero correctamente
# intento 3: 95
# El numero es demasiado bajo
# ¡Perdiste!, no lograste adivinar el numero correctamente
# intento 4: 97
# ¡Felicidades! Adivinaste el numero en 5 intentos
# El numero secreto era 97

# %%
#ejercicio 4

canon_rep=0
epson_rep=0
hp_rep=0

pedido_reparacion=int(input("Ingrese la fecha de pedido de reparacion en formato AAAAMMDD o -1 para finalizar: "))

while pedido_reparacion!=-1:
  marca=int(input("Ingrese 1(Canon), 2(Epson),3(HP): "))
  fecha_venta=int(input("Ingrese la fecha de venta en formato AAAAMMDD: "))

  año_de_venta=fecha_venta//10000
  año_reparacion=pedido_reparacion//10000

  if marca==1 and año_de_venta==2024 and año_reparacion==2024:
    canon_rep+=1
  elif marca==2 and año_de_venta==2024 and año_reparacion==2024:

    epson_rep+=1

  elif marca==3 and año_de_venta==2024 and año_reparacion==2024:
    hp_rep+=1

  pedido_reparacion=int(input("Ingrese la fecha de pedido de reparacion en formato AAAAMMDD o -1 para finalizar: "))

print(f"Se registraron {canon_rep} pedidos de reparacion para la marca canon")

print(f"Se registraron {epson_rep} pedidos de reparacion para la marca EPSON")

print(f"Se registraron {hp_rep} pedidos de reparacion para la marca HP")
# Out:
# Ingrese la fecha de pedido de reparacion en formato AAAAMMDD o -1 para finalizar: 20240618
# Ingrese 1(Canon), 2(Epson),3(HP): 3
# Ingrese la fecha de venta en formato AAAAMMDD: 20240916
# Ingrese la fecha de pedido de reparacion en formato AAAAMMDD o -1 para finalizar: -1
# Se registraron 0 pedidos de reparacion para la marca canon
# Se registraron 0 pedidos de reparacion para la marca EPSON
# Se registraron 1 pedidos de reparacion para la marca HP

# %%
#ejercicio 5

turno_1=0
turno_2=0
turno_3=0
turno_4=0
n_telefono=int(input("Ingrese el numero telefonico: "))

while n_telefono!=0:
  dia=int(input("Ingrese el dia (1-31): "))
  hora=int(input("Ingrese la hora(0-23): "))
  minutos=int(input("Ingrese los minutos(0-59): "))

  if 6 <=hora<=11 :
    turno_1+=1

  elif  12<=hora<=17 :
    turno_2+=1

  elif  18<=hora<=23:
    turno_3+=1

  elif  0<=hora<=5:
    turno_4+=1

    n_telefono=int(input("Ingrese el numero telefonico o 0 para finalizar: "))

print(f"El turno 1 tuvo un total de {turno_1} personas")
print(f"El turno 2 tuvo un total de {turno_2} personas")
print(f"El turno 3 tuvo un total de {turno_3} personas")
print(f"El turno 4 tuvo un total de {turno_4} personas")

# %%
año_l=2024
mes_l=6
dia_l=30
dia_n=int(input("Ingrese el dia de nacimiento: "))
while dia_n!=-1:

  mes_n=int(input("Ingrese el mes de nacimiento: "))
  año_n=int(input("Ingrese el año de nacimiento: "))

  año_e=año_l-año_n


  if mes_n>=mes_l:
    año_e=(año_l-año_n)-1

  elif dia_n>dia_l:
    año_e=(año_l-año_n)-1

  else:
    año_e=año_l-año_n



  if 4<=año_e<=6:
    print("Usted pertenece al curso INICIACION")

  elif 7<=año_e<=12:
    print("Usted pertenece al curso INFANCIA")

  elif 13<=año_e<=15:
    print("Usted pertenece al curso ADOLESCENTES")

  else:
    print("Usted esta fuera del rango de edad")

  dia_n=int(input("Ingrese el dia de nacimiento o -1 para finalizar: "))
# Out:
# Ingrese el dia de nacimiento: 31
# Ingrese el mes de nacimiento: 1
# Ingrese el año de nacimiento: 2011
# Usted pertenece al curso INFANCIA
# Ingrese el dia de nacimiento o -1 para finalizar: -1
